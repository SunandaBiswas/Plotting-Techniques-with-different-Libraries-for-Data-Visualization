# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
df = pd.read_csv(r"C:\Users\sunan\Downloads\THESIS\ML_FINAL_MODEL\DATASET_NANdropped\ML_Final_modeldata_nandropped.csv")
df.head()
# Out:
#    Years  Population  Total CO2 Emissions(kt)  \
# 0   1971  65733076.0                43776.646
# 1   1972  66997968.0                 7007.637
# 2   1973  68118479.0                 9094.160
# 3   1974  69248216.0                 9273.843
# 4   1975  70542557.0                 9655.211
#
#    Methane emissions (kt of CO2 equivalent)  \
# 0                                   86454.8
# 1                                   88057.2
# 2                                   88622.8
# 3                                   87762.2
# 4                                   90812.2
#
#    Nitrous oxide emissions (thousand metric tons of CO2 equivalent)  \
# 0                                           9460.425
# 1                                           9934.415
# 2                                          10077.418
# 3                                           9780.097
# 4                                          10568.644
#
#    Total greenhouse gas emissions (kt of CO2 equivalent)
# ...

# %%
df = df.set_index('Years')
df.head()
# Out:
#        Population  Total CO2 Emissions(kt)  \
# Years
# 1971   65733076.0                43776.646
# 1972   66997968.0                 7007.637
# 1973   68118479.0                 9094.160
# 1974   69248216.0                 9273.843
# 1975   70542557.0                 9655.211
#
#        Methane emissions (kt of CO2 equivalent)  \
# Years
# 1971                                    86454.8
# 1972                                    88057.2
# 1973                                    88622.8
# 1974                                    87762.2
# 1975                                    90812.2
#
#        Nitrous oxide emissions (thousand metric tons of CO2 equivalent)  \
# Years
# 1971                                            9460.425
# 1972                                            9934.415
# 1973                                           10077.418
# 1974                                            9780.097
# 1975                                           10568.644
#
# ...

# %%
df.plot(kind='density', subplots=True, layout = (2,2), sharex = False, figsize = (5,5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-bbd79db7d838> in <module>
# ----> 1 df.plot(kind='density', subplots=True, layout = (2,2), sharex = False, figsize = (5,5))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
# ...
