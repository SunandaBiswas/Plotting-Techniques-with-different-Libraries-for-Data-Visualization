# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
df = pd.read_csv(r"C:\Users\sunan\Downloads\THESIS\ML_FINAL_MODEL\DATASET_NANdropped\finaldata.csv")
df.head()
# Out:
#    Years  CO2 emissions (kt)  CO2 emissions (metric tons per capita)  \
# 0   1960           14154.620                                0.294805
# 1   1961           14656.999                                0.296924
# 2   1962           16105.464                                0.317336
# 3   1963           18514.683                                0.354674
# 4   1964           19035.397                                0.354202
#
#    CO2 emissions from gaseous fuel consumption (kt)  \
# 0                                          1133.103
# 1                                          1375.125
# 2                                          1697.821
# 3                                          2126.860
# 4                                          2673.243
#
#    CO2 emissions from liquid fuel consumption (kt)  \
# 0                                         6552.929
# 1                                         6857.290
# 2                                         7521.017
# ...

# %%
df = df.set_index('Years')
df.head()
# Out:
#        CO2 emissions (kt)  CO2 emissions (metric tons per capita)  \
# Years
# 1960            14154.620                                0.294805
# 1961            14656.999                                0.296924
# 1962            16105.464                                0.317336
# 1963            18514.683                                0.354674
# 1964            19035.397                                0.354202
#
#        CO2 emissions from gaseous fuel consumption (kt)  \
# Years
# 1960                                           1133.103
# 1961                                           1375.125
# 1962                                           1697.821
# 1963                                           2126.860
# 1964                                           2673.243
#
#        CO2 emissions from liquid fuel consumption (kt)  \
# Years
# 1960                                          6552.929
# 1961                                          6857.290
# ...

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>
